# %% [markdown]
# # Bash Commands

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)

# %%
# !pip install -U sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.32.1)
# Requirement already satisfied: tqdm in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (2.1.0)
# Requirement already satisfied: torchvision in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.16.0)
# Requirement already satisfied: numpy in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.15.1)
# Requirement already satisfied: filelock in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.9.0)
# Requirement already satisfied: fsspec in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.4.0)
# Requirement already satisfied: requests in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.2)
# Requirement already satisfied: click in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk->sentence_transformers) (8.0.4)
# Requirement already satisfied: joblib in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %% [markdown]
# # Pre- requisites

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hiteshchoudhary2109/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hiteshchoudhary2109/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import spacy

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# !python -m spacy download en_core_web_sm
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 9.1 MB/s eta 0:00:0000:01:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hiteshchoudhary2109/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.7.0
#     Uninstalling en-core-web-sm-3.7.0:
#       Successfully uninstalled en-core-web-sm-3.7.0
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Class

# %%
class embedder:
    def __init__ (self,address,model):
        file = open(address)
        self.data = json.load(file)
        self.model = model
        file.close()
    def embed_sentences(self,strings):
        embeddings = []
        for string in strings:
            embeddings.append(np.array(model.encode(string), dtype=np.float32))
        return np.array(embeddings)
    def extract(self):
        self.tools = []
        self.tool_descriptions = []
        self.arg_names = []
        self.arg_descriptions = []
        self.arg_to_tool_map = {}
        for key, value in self.data.items():
            tmp_tool = key
            self.tools.append(tmp_tool)
            
            tmp_tool_dsc = value.get("Description")
            self.tool_descriptions.append(tmp_tool_dsc)
            
            tmp_arg_dsc = value.get("ArgumentName")
        
            for argName, argDesc in tmp_arg_dsc.items():
                if (argDesc.get("Description") == "_"):
                    self.arg_names.append(key)
                    self.arg_descriptions.append(tmp_tool_dsc)
                    self.arg_to_tool_map[key] =key
                else:
                    self.arg_names.append(argName)
                    self.arg_descriptions.append(argDesc.get("Description"))
                    self.arg_to_tool_map[argName] =key
    def encode(self):
        self.tool_enc = self.embed_sentences(self.tools)
        self.tool_des_enc = self.embed_sentences(self.tool_descriptions)
        self.arg_enc = self.embed_sentences(self.arg_names)
        self.arg_des_enc = self.embed_sentences(self.arg_descriptions)
    def remove_stopwords(self,query):
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(query)
        filtered_query = [word for word in word_tokens if word.lower() not in stop_words]
        return ' '.join(filtered_query)
    def check(self,queries):
        self.tables = {}
        for query in queries:
            qenc = self.model.encode(query)
            table = {}
            for arg, arg_enc in zip(self.arg_names, self.arg_des_enc):
                table[arg] = util.cos_sim(qenc, arg_enc)
            self.tables[query] = table
        return self.tables
    def check_without_stopwords(self,queries):
        self.tables = {}
        for query in queries:
            quer = self.remove_stopwords(query)
            qenc = self.model.encode(quer)
            table = {}
            for arg, arg_enc in zip(self.arg_names, self.arg_des_enc):
                table[arg] = util.cos_sim(qenc, arg_enc)
            self.tables[query] = table
        return self.tables

# %% [markdown]
# # Practice

# %%
example = embedder("tools_dictionary.json",model)
example.extract()
example.encode()
print(example.arg_names[2])
# Out:
# get_sprint_id

# %%
queries = [
    'Get all work items similar to TKT-123, summarize them, create issues from that summary, and prioritize them',
    'Given a customer meeting transcript T, create action items and add them to my current sprint',
    'List all high severity tickets coming in from slack from customer Cust123 and generate a summary of them.',
    'What are my all issues in the triage stage under part FEAT-123? Summarize them.',
    'Summarize high severity tickets from the customer UltimateCustomer',
    'Prioritize my P0 issues and add them to the current sprint',
    'What is the meaning of life?',
    'Summarize issues similar to don:core:dvrv-us-1:devo/0:issue/1'
]
ans = example.check(queries)
fd = pd.DataFrame(ans)
fd
# Out:
#                       Get all work items similar to TKT-123, summarize them, create issues from that summary, and prioritize them  \
# text                                                  [[tensor(0.2693)]]
# work_id                                               [[tensor(0.2902)]]
# get_sprint_id                                         [[tensor(0.0345)]]
# objects                                               [[tensor(0.4640)]]
# query                                                 [[tensor(0.0178)]]
# who_am_i                                             [[tensor(-0.0926)]]
# applies_to_part                                       [[tensor(0.3315)]]
# created_by                                            [[tensor(0.2264)]]
# issue.priority                                        [[tensor(0.3121)]]
# issue.rev_orgs                                        [[tensor(0.1548)]]
# limit                                                 [[tensor(0.1932)]]
# owned_by                                              [[tensor(0.1966)]]
# stage.name                                            [[tensor(0.1521)]]
# ticket.needs_response                                 [[tensor(0.1482)]]
# ticket.rev_org                                        [[tensor(0.0667)]]
# ticket.severity                                       [[tensor(0.0433)]]
# _                                                     [[tensor(0.0716)]]
# ticket.source_channel                                 [[tensor(0.0766)]]
# type                                                  [[tensor(0.3528)]]
# work_ids                                              [[tensor(0.3500)]]
# sprint_id                                             [[tensor(0.3025)]]
#
#                       Given a customer meeting transcript T, create action items and add them to my current sprint  \
# text                                                  [[tensor(0.3375)]]
# work_id                                               [[tensor(0.2009)]]
# get_sprint_id                                         [[tensor(0.3797)]]
# objects                                               [[tensor(0.1308)]]
# query                                                 [[tensor(0.1293)]]
# who_am_i                                             [[tensor(-0.0195)]]
# applies_to_part                                       [[tensor(0.0586)]]
# created_by                                            [[tensor(0.0690)]]
# issue.priority                                        [[tensor(0.0308)]]
# issue.rev_orgs                                        [[tensor(0.0727)]]
# limit                                                 [[tensor(0.0288)]]
# owned_by                                              [[tensor(0.0020)]]
# stage.name                                            [[tensor(0.0977)]]
# ticket.needs_response                                 [[tensor(0.1757)]]
# ticket.rev_org                                        [[tensor(0.1818)]]
# ticket.severity                                       [[tensor(0.1092)]]
# _                                                    [[tensor(-0.0131)]]
# ticket.source_channel                                 [[tensor(0.1385)]]
# type                                                  [[tensor(0.1430)]]
# work_ids                                              [[tensor(0.5913)]]
# sprint_id                                             [[tensor(0.5479)]]
#
#                       List all high severity tickets coming in from slack from customer Cust123 and generate a summary of them.  \
# text                                                  [[tensor(0.1868)]]
# work_id                                               [[tensor(0.1285)]]
# get_sprint_id                                         [[tensor(0.1876)]]
# objects                                               [[tensor(0.2699)]]
# query                                                 [[tensor(0.1355)]]
# who_am_i                                              [[tensor(0.0090)]]
# applies_to_part                                       [[tensor(0.0551)]]
# created_by                                            [[tensor(0.0637)]]
# issue.priority                                        [[tensor(0.2446)]]
# issue.rev_orgs                                        [[tensor(0.0927)]]
# limit                                                 [[tensor(0.1180)]]
# owned_by                                              [[tensor(0.0584)]]
# stage.name                                            [[tensor(0.1506)]]
# ticket.needs_response                                 [[tensor(0.4466)]]
# ticket.rev_org                                        [[tensor(0.3697)]]
# ticket.severity                                       [[tensor(0.3819)]]
# _                                                     [[tensor(0.0889)]]
# ticket.source_channel                                 [[tensor(0.3479)]]
# type                                                  [[tensor(0.3506)]]
# work_ids                                              [[tensor(0.3020)]]
# sprint_id                                             [[tensor(0.1792)]]
#
#                       What are my all issues in the triage stage under part FEAT-123? Summarize them.  \
# text                                                  [[tensor(0.1682)]]
# work_id                                              [[tensor(-0.0320)]]
# get_sprint_id                                         [[tensor(0.0415)]]
# objects                                               [[tensor(0.0355)]]
# query                                                 [[tensor(0.0910)]]
# who_am_i                                             [[tensor(-0.0379)]]
# applies_to_part                                       [[tensor(0.0712)]]
# created_by                                           [[tensor(-0.0654)]]
# issue.priority                                        [[tensor(0.1894)]]
# issue.rev_orgs                                        [[tensor(0.1249)]]
# limit                                                 [[tensor(0.0924)]]
# owned_by                                             [[tensor(-0.0836)]]
# stage.name                                            [[tensor(0.1056)]]
# ticket.needs_response                                 [[tensor(0.0431)]]
# ticket.rev_org                                        [[tensor(0.0398)]]
# ticket.severity                                       [[tensor(0.0298)]]
# _                                                     [[tensor(0.0077)]]
# ticket.source_channel                                 [[tensor(0.0064)]]
# type                                                  [[tensor(0.1807)]]
# work_ids                                              [[tensor(0.0605)]]
# sprint_id                                             [[tensor(0.0677)]]
#
#                       Summarize high severity tickets from the customer UltimateCustomer  \
# text                                                  [[tensor(0.2146)]]
# work_id                                               [[tensor(0.0587)]]
# get_sprint_id                                         [[tensor(0.1240)]]
# objects                                               [[tensor(0.3125)]]
# query                                                 [[tensor(0.1204)]]
# who_am_i                                             [[tensor(-0.0044)]]
# applies_to_part                                       [[tensor(0.0479)]]
# created_by                                            [[tensor(0.0181)]]
# issue.priority                                        [[tensor(0.2554)]]
# issue.rev_orgs                                        [[tensor(0.1135)]]
# limit                                                 [[tensor(0.1299)]]
# owned_by                                              [[tensor(0.0427)]]
# stage.name                                            [[tensor(0.1906)]]
# ticket.needs_response                                 [[tensor(0.5336)]]
# ticket.rev_org                                        [[tensor(0.4311)]]
# ticket.severity                                       [[tensor(0.4631)]]
# _                                                     [[tensor(0.1073)]]
# ticket.source_channel                                 [[tensor(0.3835)]]
# type                                                  [[tensor(0.3432)]]
# work_ids                                              [[tensor(0.2382)]]
# sprint_id                                             [[tensor(0.1208)]]
#
#                       Prioritize my P0 issues and add them to the current sprint  \
# text                                                  [[tensor(0.0915)]]
# work_id                                               [[tensor(0.0047)]]
# get_sprint_id                                         [[tensor(0.3231)]]
# objects                                              [[tensor(-0.0045)]]
# query                                                [[tensor(-0.0350)]]
# who_am_i                                             [[tensor(-0.1088)]]
# applies_to_part                                       [[tensor(0.0254)]]
# created_by                                           [[tensor(-0.0282)]]
# issue.priority                                        [[tensor(0.3604)]]
# issue.rev_orgs                                        [[tensor(0.0649)]]
# limit                                                 [[tensor(0.0899)]]
# owned_by                                             [[tensor(-0.0369)]]
# stage.name                                           [[tensor(-0.0029)]]
# ticket.needs_response                                 [[tensor(0.0854)]]
# ticket.rev_org                                        [[tensor(0.0371)]]
# ticket.severity                                       [[tensor(0.0226)]]
# _                                                     [[tensor(0.0576)]]
# ticket.source_channel                                 [[tensor(0.0510)]]
# type                                                  [[tensor(0.0966)]]
# work_ids                                              [[tensor(0.3899)]]
# sprint_id                                             [[tensor(0.4223)]]
#
#                       What is the meaning of life?  \
# text                            [[tensor(0.2365)]]
# work_id                         [[tensor(0.0404)]]
# get_sprint_id                   [[tensor(0.0989)]]
# objects                         [[tensor(0.1341)]]
# query                           [[tensor(0.1401)]]
# who_am_i                        [[tensor(0.1166)]]
# applies_to_part                 [[tensor(0.0467)]]
# created_by                      [[tensor(0.0426)]]
# issue.priority                  [[tensor(0.0184)]]
# issue.rev_orgs                 [[tensor(-0.0311)]]
# limit                           [[tensor(0.1015)]]
# owned_by                        [[tensor(0.0158)]]
# stage.name                      [[tensor(0.0413)]]
# ticket.needs_response           [[tensor(0.0831)]]
# ticket.rev_org                  [[tensor(0.0364)]]
# ticket.severity                 [[tensor(0.0945)]]
# _                               [[tensor(0.0354)]]
# ticket.source_channel           [[tensor(0.0401)]]
# type                            [[tensor(0.0482)]]
# work_ids                        [[tensor(0.0739)]]
# sprint_id                       [[tensor(0.0697)]]
#
#                       Summarize issues similar to don:core:dvrv-us-1:devo/0:issue/1
# text                                                  [[tensor(0.1582)]]
# work_id                                               [[tensor(0.0198)]]
# get_sprint_id                                         [[tensor(0.0155)]]
# objects                                               [[tensor(0.2086)]]
# query                                                 [[tensor(0.0196)]]
# who_am_i                                             [[tensor(-0.0885)]]
# applies_to_part                                       [[tensor(0.0077)]]
# created_by                                            [[tensor(0.0175)]]
# issue.priority                                        [[tensor(0.1548)]]
# issue.rev_orgs                                        [[tensor(0.1483)]]
# limit                                                 [[tensor(0.1322)]]
# owned_by                                             [[tensor(-0.0003)]]
# stage.name                                            [[tensor(0.0407)]]
# ticket.needs_response                                 [[tensor(0.0643)]]
# ticket.rev_org                                        [[tensor(0.0802)]]
# ticket.severity                                       [[tensor(0.0647)]]
# _                                                     [[tensor(0.1214)]]
# ticket.source_channel                                 [[tensor(0.1569)]]
# type                                                  [[tensor(0.1355)]]
# work_ids                                              [[tensor(0.1178)]]
# sprint_id                                             [[tensor(0.0841)]]

# %%
querries = [
    'Get all work items similar to TKT-123, summarize them, create issues from that summary, and prioritize them',
    'Given a customer meeting transcript T, create action items and add them to my current sprint',
    'List all high severity tickets coming in from slack from customer Cust123 and generate a summary of them.',
    'What are my all issues in the triage stage under part FEAT-123? Summarize them.',
    'Summarize high severity tickets from the customer UltimateCustomer',
    'Prioritize my P0 issues and add them to the current sprint',
    'What is the meaning of life?',
    'Summarize issues similar to don:core:dvrv-us-1:devo/0:issue/1'
]
ans = example.check_without_stopwords(querries)
fd = pd.DataFrame(ans)
fd
# Out:
#                       Get all work items similar to TKT-123, summarize them, create issues from that summary, and prioritize them  \
# text                                                  [[tensor(0.2948)]]
# work_id                                               [[tensor(0.4377)]]
# get_sprint_id                                         [[tensor(0.0970)]]
# objects                                               [[tensor(0.5151)]]
# query                                                 [[tensor(0.1079)]]
# who_am_i                                             [[tensor(-0.0338)]]
# applies_to_part                                       [[tensor(0.3265)]]
# created_by                                            [[tensor(0.2534)]]
# issue.priority                                        [[tensor(0.2798)]]
# issue.rev_orgs                                        [[tensor(0.1310)]]
# limit                                                 [[tensor(0.2184)]]
# owned_by                                              [[tensor(0.2007)]]
# stage.name                                            [[tensor(0.1820)]]
# ticket.needs_response                                 [[tensor(0.1684)]]
# ticket.rev_org                                        [[tensor(0.0907)]]
# ticket.severity                                       [[tensor(0.0440)]]
# _                                                     [[tensor(0.0703)]]
# ticket.source_channel                                 [[tensor(0.0839)]]
# type                                                  [[tensor(0.3737)]]
# work_ids                                              [[tensor(0.4084)]]
# sprint_id                                             [[tensor(0.3589)]]
#
#                       Given a customer meeting transcript T, create action items and add them to my current sprint  \
# text                                                  [[tensor(0.3341)]]
# work_id                                               [[tensor(0.2015)]]
# get_sprint_id                                         [[tensor(0.4245)]]
# objects                                               [[tensor(0.1239)]]
# query                                                 [[tensor(0.1479)]]
# who_am_i                                              [[tensor(0.0498)]]
# applies_to_part                                       [[tensor(0.0335)]]
# created_by                                            [[tensor(0.0524)]]
# issue.priority                                        [[tensor(0.0264)]]
# issue.rev_orgs                                        [[tensor(0.0473)]]
# limit                                                 [[tensor(0.0519)]]
# owned_by                                             [[tensor(-0.0230)]]
# stage.name                                            [[tensor(0.1029)]]
# ticket.needs_response                                 [[tensor(0.1520)]]
# ticket.rev_org                                        [[tensor(0.1615)]]
# ticket.severity                                       [[tensor(0.0959)]]
# _                                                    [[tensor(-0.0149)]]
# ticket.source_channel                                 [[tensor(0.1260)]]
# type                                                  [[tensor(0.1216)]]
# work_ids                                              [[tensor(0.5789)]]
# sprint_id                                             [[tensor(0.5485)]]
#
#                       List all high severity tickets coming in from slack from customer Cust123 and generate a summary of them.  \
# text                                                  [[tensor(0.2377)]]
# work_id                                               [[tensor(0.1327)]]
# get_sprint_id                                         [[tensor(0.1650)]]
# objects                                               [[tensor(0.3479)]]
# query                                                 [[tensor(0.1400)]]
# who_am_i                                              [[tensor(0.0197)]]
# applies_to_part                                       [[tensor(0.0677)]]
# created_by                                            [[tensor(0.0799)]]
# issue.priority                                        [[tensor(0.2341)]]
# issue.rev_orgs                                        [[tensor(0.0807)]]
# limit                                                 [[tensor(0.1688)]]
# owned_by                                              [[tensor(0.0596)]]
# stage.name                                            [[tensor(0.1449)]]
# ticket.needs_response                                 [[tensor(0.4089)]]
# ticket.rev_org                                        [[tensor(0.3313)]]
# ticket.severity                                       [[tensor(0.3661)]]
# _                                                     [[tensor(0.1156)]]
# ticket.source_channel                                 [[tensor(0.3114)]]
# type                                                  [[tensor(0.3383)]]
# work_ids                                              [[tensor(0.3225)]]
# sprint_id                                             [[tensor(0.1999)]]
#
#                       What are my all issues in the triage stage under part FEAT-123? Summarize them.  \
# text                                                  [[tensor(0.1817)]]
# work_id                                               [[tensor(0.0255)]]
# get_sprint_id                                         [[tensor(0.0751)]]
# objects                                               [[tensor(0.0781)]]
# query                                                 [[tensor(0.1146)]]
# who_am_i                                             [[tensor(-0.0448)]]
# applies_to_part                                       [[tensor(0.0558)]]
# created_by                                           [[tensor(-0.0823)]]
# issue.priority                                        [[tensor(0.1539)]]
# issue.rev_orgs                                        [[tensor(0.0938)]]
# limit                                                 [[tensor(0.1097)]]
# owned_by                                             [[tensor(-0.1133)]]
# stage.name                                            [[tensor(0.1851)]]
# ticket.needs_response                                 [[tensor(0.0259)]]
# ticket.rev_org                                        [[tensor(0.0569)]]
# ticket.severity                                       [[tensor(0.0313)]]
# _                                                    [[tensor(-0.0229)]]
# ticket.source_channel                                 [[tensor(0.0260)]]
# type                                                  [[tensor(0.1707)]]
# work_ids                                              [[tensor(0.0850)]]
# sprint_id                                             [[tensor(0.0987)]]
#
#                       Summarize high severity tickets from the customer UltimateCustomer  \
# text                                                  [[tensor(0.2234)]]
# work_id                                               [[tensor(0.0496)]]
# get_sprint_id                                         [[tensor(0.1066)]]
# objects                                               [[tensor(0.3333)]]
# query                                                 [[tensor(0.1141)]]
# who_am_i                                             [[tensor(-0.0143)]]
# applies_to_part                                       [[tensor(0.0444)]]
# created_by                                            [[tensor(0.0179)]]
# issue.priority                                        [[tensor(0.2527)]]
# issue.rev_orgs                                        [[tensor(0.1058)]]
# limit                                                 [[tensor(0.1241)]]
# owned_by                                              [[tensor(0.0386)]]
# stage.name                                            [[tensor(0.1797)]]
# ticket.needs_response                                 [[tensor(0.5125)]]
# ticket.rev_org                                        [[tensor(0.4164)]]
# ticket.severity                                       [[tensor(0.4487)]]
# _                                                     [[tensor(0.1336)]]
# ticket.source_channel                                 [[tensor(0.3621)]]
# type                                                  [[tensor(0.3454)]]
# work_ids                                              [[tensor(0.2386)]]
# sprint_id                                             [[tensor(0.1186)]]
#
#                       Prioritize my P0 issues and add them to the current sprint  \
# text                                                  [[tensor(0.0604)]]
# work_id                                               [[tensor(0.0154)]]
# get_sprint_id                                         [[tensor(0.3943)]]
# objects                                              [[tensor(-0.0205)]]
# query                                                [[tensor(-0.0358)]]
# who_am_i                                             [[tensor(-0.0574)]]
# applies_to_part                                      [[tensor(-0.0353)]]
# created_by                                           [[tensor(-0.0655)]]
# issue.priority                                        [[tensor(0.3386)]]
# issue.rev_orgs                                        [[tensor(0.0102)]]
# limit                                                 [[tensor(0.1317)]]
# owned_by                                             [[tensor(-0.0738)]]
# stage.name                                           [[tensor(-0.0137)]]
# ticket.needs_response                                 [[tensor(0.0119)]]
# ticket.rev_org                                       [[tensor(-0.0020)]]
# ticket.severity                                      [[tensor(-0.0219)]]
# _                                                     [[tensor(0.0784)]]
# ticket.source_channel                                 [[tensor(0.0120)]]
# type                                                  [[tensor(0.0447)]]
# work_ids                                              [[tensor(0.3750)]]
# sprint_id                                             [[tensor(0.4351)]]
#
#                       What is the meaning of life?  \
# text                            [[tensor(0.2726)]]
# work_id                         [[tensor(0.0455)]]
# get_sprint_id                   [[tensor(0.0645)]]
# objects                         [[tensor(0.1028)]]
# query                           [[tensor(0.1024)]]
# who_am_i                        [[tensor(0.0901)]]
# applies_to_part                 [[tensor(0.0399)]]
# created_by                      [[tensor(0.0525)]]
# issue.priority                  [[tensor(0.0096)]]
# issue.rev_orgs                 [[tensor(-0.0057)]]
# limit                           [[tensor(0.1065)]]
# owned_by                        [[tensor(0.0185)]]
# stage.name                      [[tensor(0.0560)]]
# ticket.needs_response           [[tensor(0.0719)]]
# ticket.rev_org                  [[tensor(0.0600)]]
# ticket.severity                 [[tensor(0.0925)]]
# _                               [[tensor(0.0475)]]
# ticket.source_channel           [[tensor(0.0505)]]
# type                            [[tensor(0.0404)]]
# work_ids                        [[tensor(0.0475)]]
# sprint_id                       [[tensor(0.0520)]]
#
#                       Summarize issues similar to don:core:dvrv-us-1:devo/0:issue/1
# text                                                  [[tensor(0.1332)]]
# work_id                                               [[tensor(0.0074)]]
# get_sprint_id                                         [[tensor(0.0248)]]
# objects                                               [[tensor(0.1587)]]
# query                                                 [[tensor(0.0271)]]
# who_am_i                                             [[tensor(-0.0600)]]
# applies_to_part                                      [[tensor(-0.0255)]]
# created_by                                           [[tensor(-0.0202)]]
# issue.priority                                        [[tensor(0.1329)]]
# issue.rev_orgs                                        [[tensor(0.1413)]]
# limit                                                 [[tensor(0.1293)]]
# owned_by                                             [[tensor(-0.0434)]]
# stage.name                                            [[tensor(0.0135)]]
# ticket.needs_response                                 [[tensor(0.0344)]]
# ticket.rev_org                                        [[tensor(0.0706)]]
# ticket.severity                                       [[tensor(0.0447)]]
# _                                                     [[tensor(0.0927)]]
# ticket.source_channel                                 [[tensor(0.1330)]]
# type                                                  [[tensor(0.1216)]]
# work_ids                                              [[tensor(0.1004)]]
# sprint_id                                             [[tensor(0.0743)]]

# %% [markdown]
# # Agrim_list

# %%
layer2 = {'works_list':"work items",
          'summarize_objects':"Summarizes objects.",
          'prioritize_objects':"Sorts objects based on priority.",
          'add_work_items_to_sprint':"Adds work items to sprint",
          'get_sprint_id':"Returns ID current sprint",
          'get_similar_work_items':"get work items similar",
          'search_object_by_name':"returns id matching object in the system of record.",
          'create_actionable_tasks_from_text':"create actionable tasks from text",
          'who_am_i':"Returns ID current user, i, my , me"}

# %%
qu = 'add them to the current sprint'
t = example.comp_tool_1(qu)
df = pd.DataFrame(list(t.items()), columns=['Key', 'Value'])
print(df)
t2 = example.comp_tool_2(qu,layer2,t)
df2 = pd.DataFrame(list(t2.items()), columns=['Key', 'Value'])
df2
# Out:
#                                  Key                Value
# 0  create_actionable_tasks_from_text   [[tensor(0.0474)]]
# 1             get_similar_work_items   [[tensor(0.0191)]]
# 2                      get_sprint_id   [[tensor(0.6450)]]
# 3                 prioritize_objects  [[tensor(-0.0320)]]
# 4              search_object_by_name  [[tensor(-0.0862)]]
# 5                  summarize_objects  [[tensor(-0.0106)]]
# 6                           who_am_i   [[tensor(0.0978)]]
# 7                         works_list  [[tensor(-0.0240)]]
# 8           add_work_items_to_sprint   [[tensor(0.6473)]]
#                         Key               Value
# 0             get_sprint_id  [[tensor(0.4587)]]
# 1  add_work_items_to_sprint  [[tensor(0.7120)]]

# %% [markdown]
# 1. Create disjoint set of the tool description for 2nd level -- Agrim
# 2. Code improvement -- Hitesh
# 3. Rephrase the tool description -- Abhinav Bhaiya
# 4. 1 - 2

# %% [markdown]
# # Queries

# %% [markdown]
# # Anything extra you want to add, add here code rewriting is happening above so don't use anything!

# %% [markdown]
# Every query jhas k tools as output, goal is extract no.1 tool
# add that tool into query and use that to get new tool
# sentences ka fourier transform
# semantically reduce and split
# subqueries --(semantic splitting)
# complex queries to simple queries   --- query - sentence
#
# Fact-aware Sentence Split and Rephrase with Permutation Invariant Training - arXiv https://arxiv.org/pdf/2001.11383 --- Hitesh
# https://copyprogramming.com/howto/decompose-compound-sentence-to-simple-sentences --- Hitesh
# https://stackoverflow.com/questions/44626264/split-compound-sentences-into-simple-sentences --- Agrim
# https://towardsdatascience.com/nlp-splitting-text-into-sentences-7bbce222ef17 --- Abhinav
# https://github.com/explosion/spaCy/discussions/11122 --- Abhinav
# https://subscription.packtpub.com/book/data/9781838987312/2/ch02lvl1sec13/splitting-sentences-into-clauses -- Agrim

# %%
quu = 'Get all work items similar to TKT-123, summarize them, create issues from that summary, and prioritize them'
t = example.basic(quu,layer2,0.4)
t
# Out:
# Get all work items similar to TKT-123
#                                  Key               Value
# 0  create_actionable_tasks_from_text  [[tensor(0.3816)]]
# 1             get_similar_work_items  [[tensor(0.6598)]]
# 2                      get_sprint_id  [[tensor(0.2363)]]
# 3                 prioritize_objects  [[tensor(0.1805)]]
# 4              search_object_by_name  [[tensor(0.2138)]]
# 5                  summarize_objects  [[tensor(0.2554)]]
# 6                           who_am_i  [[tensor(0.1278)]]
# 7                         works_list  [[tensor(0.6074)]]
# 8           add_work_items_to_sprint  [[tensor(0.4773)]]
#                         Key               Value
# 0    get_similar_work_items  [[tensor(0.4423)]]
# 1                works_list  [[tensor(0.3812)]]
# 2  add_work_items_to_sprint  [[tensor(0.3452)]]
# summarize them
#                                  Key               Value
# 0  create_actionable_tasks_from_text  [[tensor(0.4258)]]
# 1             get_similar_work_items  [[tensor(0.2164)]]
# 2                      get_sprint_id  [[tensor(0.1044)]]
# 3                 prioritize_objects  [[tensor(0.1024)]]
# 4              search_object_by_name  [[tensor(0.0064)]]
# 5                  summarize_objects  [[tensor(0.4612)]]
# 6                           who_am_i  [[tensor(0.0681)]]
# 7                         works_list  [[tensor(0.0836)]]
# 8           add_work_items_to_sprint  [[tensor(0.1589)]]
#                                  Key               Value
# 0  create_actionable_tasks_from_text  [[tensor(0.3189)]]
# 1                  summarize_objects  [[tensor(0.4578)]]
# create issues from that summary
#                                  Key                Value
# 0  create_actionable_tasks_from_text   [[tensor(0.3504)]]
# 1             get_similar_work_items   [[tensor(0.1058)]]
# 2                      get_sprint_id  [[tensor(-0.0170)]]
# 3                 prioritize_objects   [[tensor(0.0126)]]
# 4              search_object_by_name  [[tensor(-0.0407)]]
# 5                  summarize_objects   [[tensor(0.3721)]]
# 6                           who_am_i  [[tensor(-0.0582)]]
# 7                         works_list   [[tensor(0.0983)]]
# 8           add_work_items_to_sprint   [[tensor(0.2087)]]
# Empty DataFrame
# Columns: [Key, Value]
# Index: []
# prioritize them
#                                  Key               Value
# 0  create_actionable_tasks_from_text  [[tensor(0.1825)]]
# 1             get_similar_work_items  [[tensor(0.1076)]]
# 2                      get_sprint_id  [[tensor(0.0313)]]
# 3                 prioritize_objects  [[tensor(0.3926)]]
# 4              search_object_by_name  [[tensor(0.1237)]]
# 5                  summarize_objects  [[tensor(0.1064)]]
# 6                           who_am_i  [[tensor(0.0148)]]
# 7                         works_list  [[tensor(0.0723)]]
# 8           add_work_items_to_sprint  [[tensor(0.0911)]]
# Empty DataFrame
# Columns: [Key, Value]
# Index: []
# {'get_similar_work_items': ['work_id'],
#  'summarize_objects': ['objects'],
#  None: []}

# %% [markdown]
# BERT
# LLAMA
# Rank by priority -- normalize the score -- weighing the argument -- binary classifier
# ek sub query ke sath full query
# transformer excel
# first order logic
